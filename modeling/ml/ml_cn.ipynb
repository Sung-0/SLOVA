# %%
import pandas as pd

df_cn = pd.read_csv("C:/Users/user/Documents/에이콘아카데미/최종/통합/경기_충남_전처리/cn_inte_v4.csv")
df_cn
# Out:
#         year  month  day        date     sm   longitude   latitude  \
# 0       2021      8   31  2021-08-31  78.02  126.615789  36.292821
# 1       2021      8   31  2021-08-31  78.02  126.615840  36.288313
# 2       2021      8   31  2021-08-31  78.02  126.621306  36.297369
# 3       2021      8   31  2021-08-31  78.02  126.621357  36.292862
# 4       2021      8   31  2021-08-31  78.02  126.621407  36.288354
# ...      ...    ...  ...         ...    ...         ...        ...
# 131055  2022      8   19  2022-08-19  97.33  126.586426  36.896585
# 131056  2022      8   19  2022-08-19  97.33  126.586480  36.892079
# 131057  2022      8   19  2022-08-19  97.33  126.586587  36.883065
# 131058  2022      8   19  2022-08-19  97.33  126.586641  36.878558
# 131059  2022      8   19  2022-08-19  97.33  126.586694  36.874052
#
#                                       geometry              법정동명 RI_NM  \
# 0               POINT (126.6157889 36.2928206)  충청남도 보령시 남포면 읍내리   읍내리
# 1       POINT (126.6158398 36.288313300000006)  충청남도 보령시 남포면 옥서리   옥서리
# 2                POINT (126.621306 36.2973688)  충청남도 보령시 남포면 옥동리   옥동리
# 3               POINT (126.6213566 36.2928616)  충청남도 보령시 성주면 개화리   개화리
# 4               POINT (126.6214071 36.2883544)  충청남도 보령시 웅천읍 수부리   수부리
# ...                                        ...               ...   ...
# 131055           POINT (126.586426 36.8965854)  충청남도 당진시 고대면 항곡리   항곡리
# 131056   POINT (126.5864797 36.89207869999999)  충청남도 당진시 정미면 봉생리   봉생리
# 131057          POINT (126.5865871 36.8830653)  충청남도 당진시 정미면 봉생리   봉생리
# 131058          POINT (126.5866408 36.8785585)  충청남도 당진시 정미면 봉생리   봉생리
# 131059   POINT (126.58669440000001 36.8740518)  충청남도 당진시 정미면 신시리   신시리
#
#                 일시  시군구  일강수량(mm)  matched_latitude  matched_longitude  \
# 0       2021-08-31  보령시     14.75         36.294455         126.614122
# 1       2021-08-31  보령시     14.75         36.289951         126.614259
# 2       2021-08-31  보령시     14.75         36.299069         126.619549
# 3       2021-08-31  보령시     14.75         36.294566         126.619685
# 4       2021-08-31  보령시     14.75         36.290062         126.619822
# ...            ...  ...       ...               ...                ...
# 131055  2022-08-19  당진시      2.00         36.897706         126.584244
# 131056  2022-08-19  당진시      2.00         36.893203         126.584386
# 131057  2022-08-19  당진시      2.00         36.884196         126.584670
# 131058  2022-08-19  당진시      2.00         36.879693         126.584812
# 131059  2022-08-19  당진시      2.00         36.875189         126.584954
#
#         matched_mean  distance_km   elevation      slope
# 0           0.853389     0.235243  194.713840  15.187278
# 1           0.829019     0.230717  221.865966  17.931559
# 2           0.588477     0.246106  200.180322  15.561956
# 3           0.748803     0.241527  266.088698  15.457399
# 4           0.777175     0.237107  279.980497  13.851199
# ...              ...          ...         ...        ...
# 131055      0.545535     0.230563   69.614467   9.477125
# 131056      0.330866     0.224217   81.268093  10.075055
# 131057      0.323184     0.211831   71.373298   8.821766
# 131058      0.397234     0.205816   68.484605   8.854384
# 131059      0.479832     0.199915   68.202692   6.816640
#
# [131060 rows x 19 columns]

# %%
df_cn.columns
# Out:
# Index(['year', 'month', 'day', 'date', 'sm', 'longitude', 'latitude',
#        'geometry', '법정동명', 'RI_NM', '일시', '시군구', '일강수량(mm)',
#        'matched_latitude', 'matched_longitude', 'matched_mean', 'distance_km',
#        'elevation', 'slope'],
#       dtype='object')

# %%
df_cnl = pd.read_csv("C:/Users/user/Documents/에이콘아카데미/최종/통합/경기_충남_전처리/cn_landslide.csv")
df_cnl
# Out:
#       연도   순번                   재난구분  시설구분_등급  상세주소 상세주소.1 상세주소.2 상세주소.3  \
# 0   2021  113  2021-08-31~09-01 집중호우  산사태_사유림  충청남도    예산군    대술면    마전리
# 1   2021  114  2021-08-31~09-01 집중호우  산사태_사유림  충청남도    예산군    대흥면    노동리
# 2   2021  115  2021-08-31~09-01 집중호우  산사태_사유림  충청남도    예산군    대흥면   하탄방리
# 3   2021  116  2021-08-31~09-01 집중호우  산사태_사유림  충청남도    예산군    대흥면    갈신리
# 4   2021  117  2021-08-31~09-01 집중호우  산사태_사유림  충청남도    예산군    대흥면    손지리
# ..   ...  ...                    ...      ...   ...    ...    ...    ...
# 89  2022  354       2022-08-08~08-17  산사태_사유림  충청남도    청양군    장평면    적곡리
# 90  2022  355       2022-08-08~08-17  산사태_사유림  충청남도    청양군    장평면    분향리
# 91  2022  356       2022-08-08~08-17  산사태_사유림  충청남도    청양군    남양면    봉암리
# 92  2022  361       2022-08-19~08-20  산사태_국유림  충청남도    청양군    장평면    화산리
# 93  2022  362       2022-08-19~08-20  산사태_국유림  충청남도    옥천군    청산면    대성리
#
#     피해물량(ha)   start_day
# 0      0.600  2021-08-31
# 1      0.300  2021-08-31
# 2      0.300  2021-08-31
# 3      0.500  2021-08-31
# 4      0.300  2021-08-31
# ..       ...         ...
# 89     2.400  2022-08-08
# 90     1.900  2022-08-08
# 91     0.200  2022-08-08
# 92     0.375  2022-08-19
# 93     1.000  2022-08-19
#
# [94 rows x 10 columns]

# %%
df_cnl['상세주소.2'].unique()
# Out:
# array(['대술면', '대흥면', '홍북읍', '읍내동', '인지면', '동문동', '미산면', '청소면', '주포면',
#        '청라면', '은산면', '외산면', '내산면', '규암면', '구룡면', '장평면', '정산면', '청남면',
#        '남양면', '대치면', '운곡면', '비봉면', '청산면'], dtype=object)

# %%
df_cnl['상세주소.3'].unique()
# Out:
# array(['마전리', '노동리', '하탄방리', '갈신리', '손지리', '장복리', '중계리', nan, '화수리',
#        '늑전리', '진죽리', '연지리', '나원리', '나령리', '가곡리', '신대리', '경둔리', '전장리',
#        '장벌리', '홍산리', '문신리', '온해리', '대양리', '수신리', '각대리', '거전리', '함양리',
#        '화성리', '주암리', '오번리', '현암리', '금공리', '비암리', '죽림리', '송학리', '대흥리',
#        '화산리', '용마리', '구치리', '작천리', '온직리', '락지리', '지천리', '신원리', '개곡리',
#        '적곡리', '분향리', '봉암리', '대성리'], dtype=object)

# %%
df_cnl[df_cnl['상세주소.3'].isnull()]
# Out:
#      연도  순번              재난구분  시설구분_등급  상세주소 상세주소.1 상세주소.2 상세주소.3  피해물량(ha)  \
# 7  2022   3  2022-06-28~07-01  산사태_국유림  충청남도    서산시    읍내동    NaN      0.02
# 9  2022   5  2022-06-28~07-01  산사태_국유림  충청남도    서산시    동문동    NaN      0.10
#
#     start_day
# 7  2022-06-28
# 9  2022-06-28

# %%
df = df_cn['RI_NM'].unique().tolist()

# %%
for i in df:
    if i.endswith('리'): 
        print(i)
# Out:
# 읍내리
# 옥서리
# 옥동리
# 개화리
# 수부리
# 성주리
# 창동리
# 향천리
# 평리
# 동오리
# 용수리
# 평라리
# 삼곡리
# 풍계리
# 늑전리
# 삼계리
# 금암리
# 심동리
# 도화담리
# 대농리
# 남심리
# 의평리
# 마대리
# 내평리
# 풍산리
# 나원리
# 만수리
# 봉성리
# 은현리
# 복대리
# 반교리
# 도흥리
# 옥현리
# 대덕리
# 삼산리
# 가덕리
# 중양리
# 지선리
# 장항리
# 갈산리
# 홍연리
# 전장리
# 상기리
# 학산리
# 비암리
# 복덕리
# 금지리
# 수신리
# 지티리
# 백금리
# 문신리
# 화성리
# 토정리
# 용마리
# 온해리
# 상천리
# 흥산리
# 매곡리
# 마전리
# 나령리
# 모항리
# 파도리
# 신진도리
# 의항리
# 송현리
# 정죽리
# 신덕리
# 소근리
# 황촌리
# 신두리
# 도황리
# 법산리
# 영전리
# 방갈리
# 동해리
# 마금리
# 용신리
# 이곡리
# 장대리
# 시목리
# 반계리
# 대기리
# 수룡리
# 안기리
# 포지리
# 두야리
# 양산리
# 사창리
# 마산리
# 장산리
# 몽산리
# 관리
# 당산리
# 삭선리
# 남산리
# 진산리
# 신장리
# 신온리
# 남문리
# 달산리
# 내리
# 양잠리
# 원청리
# 당암리
# 고내리
# 황화정리
# 소룡리
# 중산리
# 송림리
# 송석리
# 죽산리
# 한성리
# 월포리
# 장구리
# 옥산리
# 남전리
# 종천리
# 당정리
# 수성리
# 상좌리
# 산천리
# 화산리
# 신송리
# 옥남리
# 장암리
# 저산리
# 우라리
# 문곡리
# 구암리
# 봉남리
# 옥북리
# 화천리
# 현암리
# 흥림리
# 지석리
# 도만리
# 오석리
# 군사리
# 신창리
# 후동리
# 사곡리
# 판교리
# 계동리
# 만덕리
# 석촌리
# 어리
# 덕암리
# 창선2리
# 창선1리
# 화금리
# 금덕리
# 등고리
# 북산리
# 태월리
# 송내리
# 원수리
# 금복리
# 장선리
# 수암리
# 신포리
# 도삼리
# 당선리
# 송암리
# 동문리
# 상옥리
# 산후리
# 평천리
# 반곡리
# 어은리
# 도내리
# 인평리
# 가사리
# 송시리
# 갈마리
# 봉락리
# 진장리
# 칠전리
# 마룡리
# 어송리
# 강수리
# 창리
# 대두리
# 취평리
# 차리
# 월계리
# 강당리
# 남정리
# 지산리
# 화수리
# 애정리
# 산동리
# 창기리
# 승언리
# 중장리
# 정당리
# 신야리
# 삽시도리
# 장곡리
# 황도리
# 누동리
# 원산도리
# 고남리
# 효자도리
# 청산리
# 호리
# 독곶리
# 고파도리
# 오지리
# 덕송리
# 대황리
# 양길리
# 흑석리
# 중왕리
# 웅도리
# 금학리
# 기은리
# 대로리
# 연화리
# 도성리
# 산성리
# 장현리
# 성리
# 화곡리
# 대산리
# 환성리
# 대요리
# 영탑리
# 운산리
# 학성리
# 영보리
# 하만리
# 소성리
# 낙동리
# 교성리
# 궁포리
# 진죽리
# 신죽리
# 마강리
# 화봉리
# 야현리
# 장척리
# 죽림리
# 재정리
# 정전리
# 상정리
# 옥계리
# 내현리
# 태봉리
# 대정리
# 벽계리
# 지정리
# 신진리
# 광천리
# 옹암리
# 성연리
# 황곡리
# 매현리
# 마온리
# 청광리
# 신곡리
# 소암리
# 담산리
# 옥암리
# 가정리
# 황룡리
# 월림리
# 대평리
# 남장리
# 내죽리
# 오성리
# 학계리
# 원천리
# 광성리
# 신성리
# 홍원리
# 운용리
# 죽전리
# 가송리
# 화계리
# 화암리
# 신동리
# 신풍리
# 도산리
# 간월도리
# 일람리
# 풍전리
# 둔당리
# 모월리
# 야당리
# 궁리
# 석포리
# 신정리
# 사기리
# 기산리
# 언암리
# 왕정리
# 갈현리
# 부산리
# 광리
# 상황리
# 율목리
# 상홍리
# 봉생리
# 이호리
# 거차리
# 명천리
# 기지리
# 어사리
# 문양리
# 귀밀리
# 양림리
# 정자리
# 도당리
# 부장리
# 유계리
# 웅소성리
# 양곡리
# 응평리
# 저성리
# 기포리
# 동성리
# 오두리
# 교항리
# 중리
# 홍천리
# 반양리
# 억대리
# 전천리
# 신상리
# 양천리
# 성암리
# 거성리
# 조산리
# 취생리
# 부기리
# 덕삼리
# 탑곡리
# 상성리
# 동암리
# 가구리
# 무량리
# 용암리
# 상촌리
# 행산리
# 소중리
# 관유리
# 휴암리
# 대사리
# 운곡리
# 와리
# 용호리
# 성곡리
# 원벌리
# 오학리
# 초록리
# 장요리
# 가좌리
# 삼송리
# 황락리
# 산수리
# 여미리
# 내갈리
# 형산리
# 용현리
# 대곡리
# 쌍천리
# 금국리
# 가곡리
# 신안리
# 동산리
# 장양리
# 대율리
# 용장리
# 복당리
# 공리
# 고풍리
# 외라리
# 내라리
# 대치리
# 낙상리
# 오봉리
# 상가리
# 대동리
# 갈오리
# 사천리
# 중계리
# 월산리
# 둔리
# 관산리
# 관창리
# 보령리
# 신대리
# 음현리
# 신산리
# 소양리
# 화강리
# 장계리
# 산정리
# 도둔리
# 마량리
# 소황리
# 부사리
# 신합리
# 관당리
# 죽청리
# 황교리
# 개야리
# 월리
# 월전리
# 월호리
# 구룡리
# 증산리
# 주항리
# 양기리
# 노천리
# 두룡리
# 원두리
# 칠지리
# 신흥리
# 대천리
# 대창리
# 유곡리
# 성동리
# 신구리
# 성북리
# 주야리
# 구복리
# 창암리
# 야룡리
# 남당리
# 황율리
# 율리
# 화평리
# 독산리
# 삼현리
# 양항리
# 제석리
# 소송리
# 봉덕리
# 송학리
# 고정리
# 오포리
# 은포리
# 주교리
# 연지리
# 봉당리
# 선도리
# 성내리
# 장포리
# 다사리
# 성산리
# 신검리
# 랑평리
# 신리
# 장은리
# 사호리
# 성호리
# 성남리
# 금곡리
# 목현리
# 덕실리
# 대판리
# 유송리
# 연곡리
# 가산리
# 유리
# 독정리
# 도림리
# 기로리
# 양대리
# 안궁리
# 복모리
# 양령리
# 수향리
# 대홍리
# 도하리
# 학정리
# 군서리
# 군동리
# 흑암리
# 판정리
# 소우리
# 석교리
# 요방리
# 용정리
# 문덕리
# 정촌리
# 송남리
# 모전리
# 오색당리
# 저리
# 오목리
# 천흥리
# 송전리
# 하장리
# 효계리
# 시장리
# 상장리
# 호당리
# 납안리
# 의식리
# 쌍암리
# 월랑리
# 왕림리
# 율금리
# 석곡리
# 마정리
# 와룡리
# 신방리
# 송덕리
# 신가리
# 어룡리
# 양당리
# 신갈리
# 우신리
# 매주리
# 자은가리
# 모시리
# 성환리
# 상덕리
# 부송리
# 성월리
# 수헐리
# 삼은리
# 신월리
# 봉항리
# 학봉리
# 온천리
# 만목리
# 공세리
# 월선리
# 냉정리
# 백석포리
# 모원리
# 신현리
# 산양리
# 구성리
# 강청리
# 신운리
# 아산리
# 서원리
# 창용리
# 와우리
# 역리
# 신화리
# 신봉리
# 신수리
# 신남리
# 신항리
# 관성리
# 덕성리
# 죽계리
# 신법리
# 시포리
# 삼거리
# 원남리
# 송용리
# 봉재리
# 관대리
# 산전리
# 둔포리
# 운교리
# 소동리
# 송촌리
# 신양리
# 신휴리
# 염작리
# 쌍룡리
# 신왕리
# 송곡리
# 덕전리
# 교촌리
# 남화리
# 신계리
# 천정리
# 서리
# 용원리
# 서흥리
# 운전리
# 석천리
# 동리
# 동평리
# 신사리
# 사담리
# 명덕리
# 연춘리
# 은지리
# 전곡리
# 매송리
# 상동리
# 가전리
# 오곡리
# 병천리
# 매성리
# 도원리
# 탑원리
# 용두리
# 구도리
# 광덕리
# 행암리
# 교천리
# 응원리
# 도장리
# 소사리
# 대흥리
# 대화리
# 봉양리
# 해정리
# 백자리
# 속창리
# 발산리
# 송정리
# 송연리
# 수남리
# 장송리
# 화덕리
# 양화리
# 상도리
# 부남리
# 용동리
# 향한리
# 석계리
# 정장리
# 엄사리
# 광석리
# 신암리
# 남선리
# 유동리
# 농소리
# 천호리
# 입암리
# 한삼천리
# 덕목리
# 산직리
# 검천리
# 반암리
# 두계리
# 조령리
# 사정리
# 왕대리
# 덕곡리
# 조동리
# 오산리
# 수락리
# 어곡리
# 청흥리
# 입동리
# 봉현리
# 남천리
# 해남리
# 본의리
# 백곡리
# 선학리
# 안심리
# 안양리
# 신영리
# 용봉리
# 방흥리
# 보흥리
# 어천리
# 운암리
# 죽당리
# 국동리
# 오동리
# 삼각리
# 이인리
# 대성리
# 복룡리
# 초봉리
# 옥성리
# 오룡리
# 주봉리
# 용성리
# 산의리
# 평목리
# 목동리
# 반송리
# 상서리
# 발양리
# 신웅리
# 향지리
# 화은리
# 봉산리
# 안서리
# 은곡리
# 홍양리
# 내대리
# 북촌리
# 남촌리
# 저동리
# 묘원리
# 천보리
# 교원리
# 운치리
# 정동리
# 금천리
# 나궁리
# 주암리
# 좌홍리
# 대선리
# 율암리
# 무정리
# 삼용리
# 각대리
# 신홍리
# 합수리
# 조현리
# 내곡리
# 금사리
# 회동리
# 태양리
# 논티리
# 동방리
# 내지리
# 죽교리
# 죽절리
# 주정리
# 점상리
# 천당리
# 용당리
# 수목리
# 구봉리
# 합송리
# 만지리
# 노화리
# 부여두리
# 합곡리
# 석우리
# 반산리
# 원문리
# 석동리
# 점리
# 외리
# 정암리
# 사현리
# 어물리
# 원덕리
# 덕학리
# 도신리
# 군간리
# 오덕리
# 청남리
# 현미리
# 팔충리
# 복금리
# 옥곡리
# 가신리
# 만사리
# 탑산리
# 입포리
# 비정리
# 구교리
# 지토리
# 칠산리
# 북고리
# 수고리
# 두곡리
# 동사리
# 간대리
# 청송리
# 청포리
# 반조원리
# 귀덕리
# 가회리
# 황산리
# 채산리
# 북옥리
# 채운리
# 문금리
# 내문리
# 문천리
# 유룡리
# 지장리
# 회학리
# 한천리
# 계실리
# 월가리
# 평정리
# 고성리
# 쌍달리
# 화월리
# 내산리
# 방문리
# 도천리
# 태성리
# 전평리
# 상룡리
# 반촌리
# 동곡리
# 인풍리
# 내촌리
# 목천리
# 운궁리
# 장원리
# 석송리
# 귀산리
# 오인리
# 광정리
# 보물리
# 북계리
# 요룡리
# 수촌리
# 두만리
# 청룡리
# 월곡리
# 율정리
# 구왕리
# 내흥리
# 상신리
# 마암리
# 봉곡리
# 하신리
# 공암리
# 중묵리
# 사점리
# 효제리
# 위라리
# 대리
# 모곡리
# 후덕리
# 영양리
# 미량리
# 황계리
# 죽천리
# 서초정리
# 광암리
# 가지리
# 녹문리
# 추광리
# 상갑리
# 여래미리
# 봉갑리
# 하천리
# 조평리
# 차동리
# 노동리
# 녹천리
# 명곡리
# 중흥리
# 매산리
# 봉암리
# 장승리
# 군량리
# 방한리
# 용천리
# 청수리
# 정좌리
# 대봉리
# 온암리
# 신원리
# 송방리
# 온직리
# 학당리
# 벽천리
# 적누리
# 금정리
# 장벌리
# 백천리
# 교월리
# 탄정리
# 광금리
# 구치리
# 거전리
# 수석리
# 개곡리
# 광대리
# 시전리
# 작천리
# 이화리
# 지천리
# 적곡리
# 마치리
# 천장리
# 쌍대리
# 종곡리
# 마곡리
# 수철리
# 보산원리
# 세출리
# 매당리
# 삼태리
# 보성리
# 무학리
# 풍서리
# 남관리
# 행정리
# 임화리
# 인천리
# 도평리
# 양촌리
# 채광리
# 신기리
# 원평리
# 봉림리
# 사석리
# 금치리
# 북문리
# 옥전리
# 하평리
# 고도리
# 당곡리
# 시동리
# 상하리
# 대지리
# 효교리
# 송산리
# 창정리
# 사리
# 안치리
# 이리
# 가리
# 삽교리
# 평촌리
# 용리
# 구만리
# 노은리
# 두리
# 계정리
# 하포리
# 효림리
# 주령리
# 대인리
# 별리
# 방아리
# 상궁리
# 중예리
# 양막리
# 분천리
# 좌방리
# 건지화리
# 신석리
# 증곡리
# 내량리
# 조곡리
# 역탑리
# 예림리
# 오촌리
# 후사리
# 용궁리
# 봉명리
# 대률리
# 서계양리
# 갈신리
# 귀곡리
# 시산리
# 불원리
# 궐곡리
# 연리
# 시왕리
# 농리
# 상항리
# 이티리
# 농은리
# 장복리
# 방산리
# 강장리
# 신당리
# 이사리
# 천동리
# 사월리
# 왕덕리
# 왕전리
# 죽곡리
# 부인리
# 항월리
# 송당리
# 두사리
# 유평리
# 월오리
# 덕평리
# 마구평리
# 월암리
# 신충리
# 하도리
# 아호리
# 금대리
# 화헌리
# 신교리
# 경천리
# 주곡리
# 숙진리
# 탑정리
# 지경리
# 부황리
# 하대리
# 외성리
# 종연리
# 감곡리
# 석종리
# 대촌리
# 사포리
# 장전리
# 충곡리
# 대명리
# 대우리
# 임리
# 백석리
# 표정리
# 한전리
# 고양리
# 도곡리
# 청동리
# 명암리
# 화악리
# 관동리
# 연산리
# 개척리
# 장화리
# 홍교리
# 중앙리
# 동흥리
# 남교리
# 화정리
# 우기리
# 봉동리
# 심암리
# 죽평리
# 양지리
# 왕암리
# 삼전리
# 등리
# 두월리
# 조정리
# 산노리
# 목곡리
# 병암리
# 함적리
# 거사리
# 석서리
# 모촌리
# 우곤리
# 병촌리
# 월성리
# 삼호리
# 야화리
# 원북리
# 정지리
# 원봉리
# 용화리
# 방축리
# 토양리
# 연서리
# 와야리
# 용산리
# 시묘리
# 죽본리
# 성평리
# 성덕리
# 야촌리
# 육곡리
# 금당리
# 고마리
# 망월리
# 창외리
# 황사리
# 추동리
# 옥포리
# 가공리
# 영모리
# 벽오리
# 소야리
# 삼월리
# 안당리
# 죽촌리
# 지현리
# 활동리
# 기복리
# 보현리
# 관포리
# 가양리
# 마명리
# 대등리
# 대하리
# 와초리
# 축동리
# 종지리
# 호암리
# 성외리
# 남성리
# 완포리
# 가화리
# 요곡리
# 화촌리
# 구동리
# 원산리
# 동지리
# 단상리
# 여사리
# 나교리
# 단하리
# 온동리
# 벽용리
# 마양리
# 수원리
# 연봉리
# 초왕리
# 오량리
# 족교리
# 시음리
# 원당리
# 내성리
# 암수리
# 대영리
# 노전리
# 수란리
# 구례리
# 은사리
# 광시리
# 봉서리
# 마사리
# 천태리
# 하장대리
# 록평리
# 동서리
# 상중리
# 장재리
# 관음리
# 등촌리
# 송지리
# 장신리
# 미곡리
# 입침리
# 신속리
# 대야리
# 월송리
# 지곡리
# 하탄방리
# 손지리
# 탄방리
# 무봉리
# 대회리
# 삼웅리
# 팔중리
# 성하리
# 율사리
# 자개리
# 원동리
# 옹안리
# 마교리
# 화전리
# 문봉리
# 궁평리
# 몽곡리
# 상몽리
# 나산리
# 호음리
# 오추리
# 소소리
# 본리
# 대전리
# 중방리
# 대합덕리
# 합덕리
# 도리
# 점원리
# 성원리
# 옥금리
# 신택리
# 대포리
# 신종리
# 락지리
# 내초리
# 미당리
# 대박리
# 와촌리
# 인양리
# 서정리
# 학암리
# 왕진리
# 자왕리
# 역촌리
# 청소리
# 가증리
# 광생리
# 내직리
# 동강리
# 저석리
# 송간리
# 화양리
# 천내리
# 상금리
# 견동리
# 유하리
# 분강리
# 가척리
# 대학리
# 정치리
# 세탑리
# 광명리
# 덕지리
# 시량리
# 소향리
# 사동리
# 신경리
# 목리
# 봉신리
# 오관리
# 신평리
# 내법리
# 대교리
# 월현리
# 고암리
# 송월리
# 내덕리
# 운월리
# 장성리
# 팔괘리
# 구정리
# 화신리
# 수정리
# 석택리
# 금평리
# 문당리
# 상송리
# 효학리
# 대현리
# 송강리
# 부평리
# 용흥리
# 덕정리
# 인산리
# 두남리
# 미죽리
# 삼성리
# 탄중리
# 종경리
# 발연리
# 계촌리
# 창소리
# 관작리
# 석양리
# 장곳리
# 신례원리
# 예산리
# 봉농리
# 간양리
# 신언리
# 금산리
# 효자리
# 기곡리
# 향산리
# 농암리
# 기덕리
# 광평리
# 구재리
# 양사리
# 강정리
# 규암리
# 군수리
# 동남리
# 구아리
# 왕포리
# 쌍북리
# 가탑리
# 중정리
# 장하리
# 염창리
# 사산리
# 석목리
# 능산리
# 현북리
# 하황리
# 정각리
# 봉정리
# 현내리
# 두왕리
# 둔덕리
# 문장리
# 산내리
# 신농리
# 초현리
# 선동리
# 선암리
# 두북리
# 원길리
# 내동리
# 장상리
# 막동리
# 지원리
# 용곡리
# 풍정리
# 봉선리
# 월기리
# 후암리
# 시선리
# 오번리
# 대양리
# 경둔리
# 홍산리
# 가중리
# 은산리
# 금공리
# 나복리
# 회곡리
# 모리
# 함양리
# 오수리
# 진변리
# 합정리
# 백교리
# 대룡리
# 만천리
# 입석리
# 석남리
# 백룡리
# 유구리
# 동원리
# 추계리
# 신달리
# 거산리
# 구계리
# 화흥리
# 평소리
# 영정리
# 세동리
# 연종리
# 해월리
# 가교리
# 호계리
# 부곡리
# 고당리
# 대중리
# 동대리
# 단지리
# 석성리
# 비당리
# 추양리
# 송국리
# 초평리
# 득윤리
# 진호리
# 안영리
# 효죽리
# 오강리
# 노티리
# 병사리
# 관현리
# 분향리
# 중추리
# 석당리
# 행목리
# 수곡리
# 수장리
# 염성리
# 동화리
# 곡교리
# 쌍죽리
# 동정리
# 석정리
# 석두리
# 방현리
# 동천리
# 백암리
# 교로리
# 장고항리
# 삼봉리
# 매방리
# 수당리
# 당진포리
# 통정리
# 신시리
# 사관리
# 진관리
# 천의리
# 대운산리
# 안호리
# 항곡리
# 덕마리
# 삼화리
# 슬항리
# 모평리
# 수평리
# 사기소리
# 고산리
# 무수리
# 죽동리
# 성상리
# 상거리
# 봉소리
# 도문리
# 기지시리
# 명산리
# 가학리
# 세교리
# 휴대리
# 대음리
# 신문리
# 금성리
# 문방리
# 채신언리
# 선창리
# 홍곳리
# 군덕리
# 해암리
# 가내리
# 궁화리
# 와산리
# 구령리
# 공수리
# 북수리
# 회룡리
# 호산리
# 갈매리
# 고대리
# 정곡리
# 영천리
# 초대리
# 전대리
# 한진리
# 복운리
# 한정리
# 부수리
# 운정리
# 오암리
# 외암리
# 양유리
# 옥호리
# 방계리
# 본당리
# 봉교리
# 청금리
# 아찬리
# 상오리
# 세류리
# 원치리
# 공포리
# 신촌리
# 강문리
# 소반리
# 내경리
# 돈포리
# 걸매리
# 밀두리
# 관암리
# 신통리
# 신유리
# 오사리
# 무장리
# 난지도리
# 초락도리
# 출포리
# 해성리
# 조금리
# 적서리
# 사성리
# 예덕리
# 장정리
# 마중리
# 도이리
# 두산리
# 대조리
# 하성리
# 우산리
# 승산리

# %%
ri_names = df_cnl['상세주소.3'].unique()

df_cn['history'] = df_cn['RI_NM'].isin(ri_names).astype(int)
df_cn['history'].value_counts()
# Out:
# history
# 0    124720
# 1      6340
# Name: count, dtype: int64

# %%
ml_cn = df_cn[['matched_mean','elevation', 'slope','sm','일강수량(mm)','history']]

ml_cn
# Out:
#         matched_mean   elevation      slope     sm  일강수량(mm)  history
# 0           0.853389  194.713840  15.187278  78.02     14.75        0
# 1           0.829019  221.865966  17.931559  78.02     14.75        0
# 2           0.588477  200.180322  15.561956  78.02     14.75        0
# 3           0.748803  266.088698  15.457399  78.02     14.75        0
# 4           0.777175  279.980497  13.851199  78.02     14.75        0
# ...              ...         ...        ...    ...       ...      ...
# 131055      0.545535   69.614467   9.477125  97.33      2.00        0
# 131056      0.330866   81.268093  10.075055  97.33      2.00        0
# 131057      0.323184   71.373298   8.821766  97.33      2.00        0
# 131058      0.397234   68.484605   8.854384  97.33      2.00        0
# 131059      0.479832   68.202692   6.816640  97.33      2.00        0
#
# [131060 rows x 6 columns]

# %% [markdown]
# ## 머신러닝 1차 시도 -- 로지스틱 회귀 (0,1 재현율 극단적)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


X = ml_cn[['matched_mean', 'elevation', 'slope', 'sm', '일강수량(mm)']]
y = ml_cn['history']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)


model = LogisticRegression(class_weight='balanced', random_state=42)
model.fit(X_train, y_train)


y_proba = model.predict_proba(X_test)[:, 1]
y_pred = (y_proba > 0.3).astype(int)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# [[ 4208 20736]
#  [   64  1204]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.17      0.29     24944
#            1       0.05      0.95      0.10      1268
#
#     accuracy                           0.21     26212
#    macro avg       0.52      0.56      0.20     26212
# weighted avg       0.94      0.21      0.28     26212

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid()
plt.title("Precision-Recall vs Threshold")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

X = ml_cn[['matched_mean','elevation', 'slope','sm','일강수량(mm)']]
y = ml_cn['history']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[24944     0]
#  [ 1268     0]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98     24944
#            1       0.00      0.00      0.00      1268
#
#     accuracy                           0.95     26212
#    macro avg       0.48      0.50      0.49     26212
# weighted avg       0.91      0.95      0.93     26212
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Recalculate scale_pos_weight from training set
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train XGBoost without SMOTE, just using scale_pos_weight
model_no_smote = XGBClassifier(
    scale_pos_weight=scale_pos_weight,
    eval_metric='logloss',
    random_state=42
)
model_no_smote.fit(X_train_scaled, y_train)

# Predict probabilities and apply threshold tuning
y_proba_no_smote = model_no_smote.predict_proba(X_test_scaled)[:, 1]
y_pred_no_smote = (y_proba_no_smote > 0.4).astype(int)

# Evaluate
conf_matrix_no_smote = confusion_matrix(y_test, y_pred_no_smote)
report_no_smote = classification_report(y_test, y_pred_no_smote, zero_division=0)
roc_auc_no_smote = roc_auc_score(y_test, y_proba_no_smote)

print(conf_matrix_no_smote, report_no_smote, roc_auc_no_smote)
# Out:
# [[20459  4485]
#  [  177  1091]]               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90     24944
#            1       0.20      0.86      0.32      1268
#
#     accuracy                           0.82     26212
#    macro avg       0.59      0.84      0.61     26212
# weighted avg       0.95      0.82      0.87     26212
#  0.9200684454313309

# %%
import shap
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


X = df_cn[['matched_mean', 'elevation', 'slope', 'sm', '일강수량(mm)']]
y = df_cn['history']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. XGBoost 모델 학습 (scale_pos_weight 반영)
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
model = xgb.XGBClassifier(scale_pos_weight=scale_pos_weight, eval_metric='logloss', random_state=42)
model.fit(X_train_scaled, y_train)

# 3. SHAP 분석
explainer = shap.Explainer(model)
shap_values = explainer(X_test_scaled)

# 4. 요약 그래프 (전체 변수 중요도)
shap.summary_plot(shap_values, X_test, feature_names=X.columns)

# 5. 개별 예측 해석 (예: 0번째 샘플)
shap.plots.waterfall(shap_values[0])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import shap
import pandas as pd
import numpy as np

explainer = shap.Explainer(model, X_train_scaled)
shap_values = explainer(X_test_scaled)

mean_shap_df = pd.DataFrame({
    'feature': X.columns,
    'mean_abs_shap': np.abs(shap_values.values).mean(axis=0)
}).sort_values(by='mean_abs_shap', ascending=False)

print(mean_shap_df)
# Out:
#  99%|===================| 26042/26212 [01:20<00:00]
#         feature  mean_abs_shap
# 3            sm       1.108072
# 1     elevation       0.651326
# 4      일강수량(mm)       0.554826
# 2         slope       0.366975
# 0  matched_mean       0.341592
