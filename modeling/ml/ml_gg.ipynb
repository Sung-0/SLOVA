# %%
import pandas as pd

df_gg = pd.read_csv("C:/Users/user/Documents/에이콘아카데미/최종/통합/경기_충남_전처리/gg_inte_v4.csv")
df_gg
# Out:
#         year  month  day      sm   longitude   latitude  \
# 0       2022      6   23   68.56  127.694204  37.153889
# 1       2022      6   23   68.56  127.694193  37.149381
# 2       2022      6   23   68.56  127.694181  37.144874
# 3       2022      6   23   68.56  127.694170  37.140367
# 4       2022      6   23   68.56  127.699835  37.153879
# ...      ...    ...  ...     ...         ...        ...
# 180500  2022      9    4  108.45  126.950779  37.175310
# 180501  2022      9    4  108.45  126.951657  37.053623
# 180502  2022      9    4  108.45  126.951689  37.049116
# 180503  2022      9    4  108.45  126.951722  37.044609
# 180504  2022      9    4  108.45  126.951884  37.022075
#
#                                             geometry             법정동명 RI_NM  \
# 0              POINT (127.69420439999999 37.1538885)  경기도 여주시 점동면 당진리   당진리
# 1       POINT (127.69419290000002 37.14938149999998)  경기도 여주시 점동면 관한리   관한리
# 2                     POINT (127.6941814 37.1448744)  경기도 여주시 점동면 관한리   관한리
# 3                     POINT (127.6941698 37.1403673)  경기도 여주시 점동면 관한리   관한리
# 4              POINT (127.6998352 37.15387919999999)  경기도 여주시 점동면 당진리   당진리
# ...                                              ...              ...   ...
# 180500         POINT (126.9507787 37.17531030000001)   경기도 화성시 정남면 백리    백리
# 180501                POINT (126.9516569 37.0536234)  경기도 평택시 청북읍 어소리   어소리
# 180502         POINT (126.95168940000002 37.0491164)  경기도 평택시 청북읍 어소리   어소리
# 180503         POINT (126.95172180000002 37.0446095)  경기도 평택시 청북읍 토진리   토진리
# 180504         POINT (126.95188380000002 37.0220746)  경기도 평택시 오성면 양교리   양교리
#
#                 일시  시군구  일강수량(mm)  matched_latitude  matched_longitude  \
# 0       2022-06-23  여주시    40.000         37.153985         127.696486
# 1       2022-06-23  여주시    40.000         37.149479         127.696563
# 2       2022-06-23  여주시    40.000         37.144974         127.696640
# 3       2022-06-23  여주시    40.000         37.140468         127.696718
# 4       2022-06-23  여주시    40.000         37.154047         127.702115
# ...            ...  ...       ...               ...                ...
# 180500  2022-09-04  화성시    10.375         37.175013         126.952732
# 180501  2022-09-04  평택시    10.500         37.053302         126.950386
# 180502  2022-09-04  평택시    10.500         37.048797         126.950507
# 180503  2022-09-04  평택시    10.500         37.044293         126.950628
# 180504  2022-09-04  평택시    10.500         37.021772         126.951233
#
#         matched_mean  distance_km  matched_elevation  matched_slope
# 0           0.638810     0.202466         412.488315      16.333490
# 1           0.620675     0.210348         459.240738      21.248910
# 2           0.613589     0.218231         464.567465      20.017375
# 3           0.648113     0.226123         519.436188      22.400142
# 4           0.612092     0.202917         335.324895      13.556068
# ...              ...          ...                ...            ...
# 180500      0.459676     0.176226         102.317273      11.063213
# 180501      0.363704     0.118357          38.048671       4.039405
# 180502      0.353189     0.110790          35.938312       4.143402
# 180503      0.206488     0.103266          26.317023       2.060655
# 180504      0.325241     0.066868          51.573802       4.619743
#
# [180505 rows x 18 columns]

# %%
df_gg.columns
# Out:
# Index(['year', 'month', 'day', 'sm', 'longitude', 'latitude', 'geometry',
#        '법정동명', 'RI_NM', '일시', '시군구', '일강수량(mm)', 'matched_latitude',
#        'matched_longitude', 'matched_mean', 'distance_km', 'matched_elevation',
#        'matched_slope'],
#       dtype='object')

# %%
df_ggl = pd.read_csv("C:/Users/user/Documents/에이콘아카데미/최종/통합/경기_충남_전처리/gg_landslide.csv")
df_ggl
# Out:
#        연도   순번              재난구분     시설구분_등급 상세주소 상세주소.1 상세주소.2 상세주소.3  \
# 0    2022    1  2022-06-23~06-24     산사태_국유림  경기도    파주시    탄현면    오금리
# 1    2022    2  2022-06-23~06-24  산사태_지자체소유림  경기도    군포시    속달동    NaN
# 2    2022    6  2022-06-28~07-01     산사태_국유림  경기도    연천군    청산면    백의리
# 3    2022    7  2022-06-28~07-01     산사태_국유림  경기도    양주시    덕계동    NaN
# 4    2022    8  2022-06-28~07-01     산사태_국유림  경기도    파주시    적성면    설마리
# ..    ...  ...               ...         ...  ...    ...    ...    ...
# 171  2022  358  2022-08-08~08-17     산사태_사유림  경기도    오산시    양산동    NaN
# 172  2022  359  2022-08-08~08-17  산사태_지자체소유림  경기도    이천시    모가면    어농리
# 173  2022  360  2022-08-08~08-17     산사태_사유림  경기도    이천시    신둔면    지석리
# 174  2022  374     제11호 태풍 '힌남노'     산사태_사유림  경기도    가평군    설악면    엄소리
# 175  2022  375     제11호 태풍 '힌남노'     산사태_사유림  경기도    가평군    설악면    방일리
#
#      피해물량(ha)   start_day
# 0        0.10  2022-06-23
# 1        0.18  2022-06-23
# 2        0.09  2022-06-28
# 3        0.45  2022-06-28
# 4        0.16  2022-06-28
# ..        ...         ...
# 171      0.35  2022-08-08
# 172      0.02  2022-08-08
# 173      0.02  2022-08-08
# 174      0.20  2022-09-04
# 175      0.05  2022-09-04
#
# [176 rows x 10 columns]

# %%
df_ggl['상세주소.2'].unique()
# Out:
# array(['탄현면', '속달동', '청산면', '덕계동', '적성면', '월룡면', '미산면', '장흥면', '하성면',
#        '파평면', '문산읍', '광탄면', '기흥구', '일죽면', '전곡읍', '상면', '장안구', '수정구',
#        '만안구', '덕양구', '관문동', '주암동', '부곡동', '대야미동', '둔대동', '오전동', '학의동',
#        '왕곡로', '학암동', '상산곡동', '처인구 이동읍', '수지구 고기동', '법원읍', '파주읍', '대월면',
#        '모가면', '매송면', '팔탄면', '목현동', '퇴촌면', '남한산성면', '남종면', '내촌면', '소흘읍',
#        '강천면', '산북면', '금사면', '신서면', '조종면', '청운면', '양동면', '단월면', '지평면',
#        '옥천면', '양평읍', '강하면', '강상면', '개군면', '양서면', '용문면', '서종면', '장안구 상광교동',
#        '양산동', '신둔면', '설악면'], dtype=object)

# %%
df_ggl['상세주소.3'].unique()
# Out:
# array(['오금리', nan, '백의리', '설마리', '덕은리', '유촌리', '삼화리', '석현리', '석탄리', '두포리',
#        '이천리', '창만리', '동백동', '율곡리', '화곡리', '양원리', '봉수리', '묵리', '기산리',
#        '갈곡리', '백석리', '대흥리', '산내리', '어천리', '기천리', '우산리', '도수리', '영동리',
#        '산성리', '관음리', '검복리', '공지원리', '오전리', '삼성리', '원당리', '음현리', '직동리',
#        '도전리', '백자리', '도곡리', '주어리', '명품리', '내산리', '도신리', '마일리', '갈운리',
#        '비룡리', '매월리', '금왕리', '신론리', '삼가리', '무왕리', '가현리', '용천리', '부안리',
#        '계정리', '일신리', '오빈리', '성덕리', '세월리', '산음리', '도원리', '월산리', '불곡리',
#        '삼산리', '병산리', '화양리', '고송리', '신복리', '항금리', '왕창리', '증동리', '동오리',
#        '대석리', '금곡리', '광탄리', '화전리', '석장리', '신화리', '전수리', '송학리', '서후리',
#        '복포리', '어농리', '지석리', '엄소리', '방일리'], dtype=object)

# %%
df_ggl[df_ggl['상세주소.3'].isnull()]
# Out:
#        연도   순번              재난구분     시설구분_등급 상세주소 상세주소.1    상세주소.2 상세주소.3  \
# 1    2022    2  2022-06-23~06-24  산사태_지자체소유림  경기도    군포시       속달동    NaN
# 3    2022    7  2022-06-28~07-01     산사태_국유림  경기도    양주시       덕계동    NaN
# 20   2022   54  2022-08-08~08-17  산사태_타부처국유림  경기도    수원시       장안구    NaN
# 21   2022   55  2022-08-08~08-17  산사태_지자체소유림  경기도    수원시       장안구    NaN
# 22   2022   56  2022-08-08~08-17     산사태_사유림  경기도    성남시       수정구    NaN
# 23   2022   57  2022-08-08~08-17     산사태_사유림  경기도    성남시       수정구    NaN
# 24   2022   58  2022-08-08~08-17  산사태_지자체소유림  경기도    안양시       만안구    NaN
# 25   2022   59  2022-08-08~08-17     산사태_국유림  경기도    고양시       덕양구    NaN
# 26   2022   60  2022-08-08~08-17     산사태_사유림  경기도    과천시       관문동    NaN
# 27   2022   61  2022-08-08~08-17     산사태_사유림  경기도    과천시       주암동    NaN
# 28   2022   62  2022-08-08~08-17     산사태_사유림  경기도    군포시       부곡동    NaN
# 29   2022   63  2022-08-08~08-17     산사태_사유림  경기도    군포시      대야미동    NaN
# 30   2022   64  2022-08-08~08-17     산사태_사유림  경기도    군포시       둔대동    NaN
# 31   2022   65  2022-08-08~08-17     산사태_사유림  경기도    의왕시       오전동    NaN
# 32   2022   66  2022-08-08~08-17     산사태_사유림  경기도    의왕시       학의동    NaN
# 33   2022   67  2022-08-08~08-17     산사태_사유림  경기도    의왕시       왕곡로    NaN
# 34   2022   68  2022-08-08~08-17     산사태_사유림  경기도    하남시       학암동    NaN
# 35   2022   69  2022-08-08~08-17     산사태_사유림  경기도    하남시       학암동    NaN
# 36   2022   70  2022-08-08~08-17     산사태_사유림  경기도    하남시      상산곡동    NaN
# 38   2022   72  2022-08-08~08-17     산사태_사유림  경기도    용인시   수지구 고기동    NaN
# 46   2022   80  2022-08-08~08-17     산사태_국유림  경기도    광주시       목현동    NaN
# 170  2022  357  2022-08-08~08-17     산사태_사유림  경기도    수원시  장안구 상광교동    NaN
# 171  2022  358  2022-08-08~08-17     산사태_사유림  경기도    오산시       양산동    NaN
#
#      피해물량(ha)   start_day
# 1        0.18  2022-06-23
# 3        0.45  2022-06-28
# 20       0.06  2022-08-08
# 21       0.54  2022-08-08
# 22       1.80  2022-08-08
# 23       0.46  2022-08-08
# 24       1.04  2022-08-08
# 25       0.30  2022-08-08
# 26       0.37  2022-08-08
# 27       1.18  2022-08-08
# 28       0.45  2022-08-08
# 29       0.15  2022-08-08
# 30       0.10  2022-08-08
# 31       0.43  2022-08-08
# 32       0.84  2022-08-08
# 33       0.78  2022-08-08
# 34       4.67  2022-08-08
# 35       1.82  2022-08-08
# 36       0.84  2022-08-08
# 38       0.55  2022-08-08
# 46       0.40  2022-08-08
# 170      0.09  2022-08-08
# 171      0.35  2022-08-08

# %%
df = df_gg['RI_NM'].unique().tolist()

# %%
for i in df:
    if i.endswith('리'): 
        print(i)
# Out:
# 당진리
# 관한리
# 장안리
# 삼합리
# 강천리
# 일신리
# 매월리
# 석우리
# 단석리
# 덕산리
# 고송리
# 서원리
# 중암리
# 금왕리
# 도전리
# 가현리
# 쌍학리
# 석곡리
# 갈운리
# 삼산리
# 계정리
# 장동리
# 도립리
# 경사리
# 주록리
# 송말리
# 외사리
# 조읍리
# 모전리
# 도곡리
# 도지리
# 무촌리
# 마암리
# 산촌리
# 신하리
# 내사리
# 현방리
# 아미리
# 사동리
# 내촌리
# 백우리
# 우곡리
# 죽당리
# 문장리
# 상대리
# 신원리
# 가산리
# 복대리
# 상용리
# 고백리
# 다대리
# 수정리
# 대관리
# 하다리
# 대당리
# 용은리
# 상백리
# 귀백리
# 효지리
# 신근리
# 율극리
# 도원리
# 사룡리
# 회곡리
# 신천리
# 천안리
# 선촌리
# 엄소리
# 창의리
# 방일리
# 설곡리
# 묵안리
# 가일리
# 송산리
# 위곡리
# 용천리
# 석산리
# 산음리
# 용담리
# 검천리
# 귀여리
# 양수리
# 부용리
# 도수리
# 문호리
# 목왕리
# 수청리
# 영동리
# 관음리
# 동오리
# 우산리
# 수능리
# 대심리
# 운심리
# 항금리
# 국수리
# 왕창리
# 서후리
# 청계리
# 복포리
# 성덕리
# 주어리
# 증동리
# 전수리
# 아신리
# 신복리
# 읍내리
# 마장리
# 개곡리
# 목동리
# 고성리
# 미사리
# 암산리
# 신필리
# 자석리
# 선읍리
# 방추리
# 제요리
# 심석리
# 은봉리
# 이황리
# 대서리
# 나래리
# 양귀리
# 어석리
# 연대리
# 와현리
# 풍계리
# 진암리
# 오남리
# 삼승리
# 노탑리
# 장호원리
# 원부리
# 회현리
# 앙덕리
# 창대리
# 석장리
# 신애리
# 백안리
# 구미리
# 연수리
# 공세리
# 불곡리
# 대흥리
# 하자포리
# 봉성리
# 원덕리
# 부리
# 신점리
# 삼성리
# 내리
# 오촌리
# 다문리
# 덕촌리
# 주읍리
# 화전리
# 마룡리
# 수곡리
# 중원리
# 조현리
# 금곡리
# 옥현리
# 향소리
# 송현리
# 광탄리
# 지평리
# 망능리
# 봉상리
# 월산리
# 망미리
# 대평리
# 무왕리
# 삼가리
# 걸은리
# 부평리
# 간매리
# 운촌리
# 본두리
# 안금리
# 금당리
# 청안리
# 처리
# 가정리
# 흔암리
# 사곡리
# 이호리
# 적금리
# 가야리
# 지내리
# 명성리
# 여물리
# 신론리
# 화악리
# 장흥리
# 하호리
# 외평리
# 계신리
# 궁리
# 이포리
# 천서리
# 당남리
# 양촌리
# 상자포리
# 계전리
# 자연리
# 송촌리
# 보통리
# 향리
# 당산리
# 내양리
# 도롱리
# 율촌리
# 백석리
# 계림리
# 초현리
# 왕대리
# 후포리
# 곡수리
# 윤촌리
# 장풍리
# 옥촌리
# 천남리
# 하림리
# 상구리
# 상교리
# 대석리
# 병산리
# 정배리
# 송학리
# 신화리
# 옥천리
# 오빈리
# 양근리
# 화양리
# 덕평리
# 교평리
# 세월리
# 공흥리
# 상판리
# 승안리
# 마일리
# 백둔리
# 경반리
# 두밀리
# 하색리
# 대곡리
# 적목리
# 도대리
# 이곡리
# 제령리
# 소법리
# 사직리
# 화대리
# 기산리
# 연곡리
# 장암리
# 도평리
# 남곡리
# 사암리
# 문촌리
# 고당리
# 평창리
# 좌항리
# 미평리
# 가재월리
# 두창리
# 독성리
# 맹리
# 죽능리
# 북가현리
# 해월리
# 가좌리
# 석천리
# 가창리
# 근곡리
# 근창리
# 근삼리
# 배태리
# 율곡리
# 매곡리
# 백암리
# 장평리
# 박곡리
# 백봉리
# 옥산리
# 고안리
# 내장리
# 송갈리
# 어농리
# 두미리
# 방초리
# 매산리
# 고은리
# 대죽리
# 화곡리
# 월정리
# 신흥리
# 송천리
# 용설리
# 화봉리
# 주천리
# 가리
# 능국리
# 금산리
# 산양리
# 당촌리
# 상봉리
# 수산리
# 장능리
# 산북리
# 행죽리
# 본죽리
# 장천리
# 신추리
# 송계리
# 북두리
# 오성리
# 산성리
# 월포리
# 총곡리
# 부안리
# 보룡리
# 덕수리
# 비룡리
# 용두리
# 건업리
# 상품리
# 유사리
# 명품리
# 이선리
# 백자리
# 후리
# 상호리
# 소유리
# 전북리
# 금사리
# 송림리
# 뇌곡리
# 부구리
# 성신리
# 현수리
# 도리
# 굴암리
# 산내리
# 진가리
# 송곡리
# 대대리
# 서경리
# 도리리
# 원두리
# 양평리
# 초지리
# 군량리
# 소사리
# 구시리
# 부필리
# 송라리
# 응암리
# 송온리
# 대신리
# 매화리
# 양거리
# 상활리
# 신해리
# 태평리
# 정단리
# 건장리
# 매류리
# 마래리
# 오산리
# 삼군리
# 화평리
# 신지리
# 광대리
# 하귀리
# 구양리
# 번도리
# 오계리
# 외룡리
# 신남리
# 당우리
# 내룡리
# 주암리
# 신접리
# 진우리
# 용면리
# 노곡리
# 관리
# 수양리
# 고척리
# 인후리
# 신촌리
# 마교리
# 수광리
# 소정리
# 수남리
# 남정리
# 봉현리
# 지석리
# 목리
# 수하리
# 표교리
# 안평리
# 도암리
# 유산리
# 후안리
# 도봉리
# 신대리
# 동평리
# 남풍리
# 기솔리
# 내강리
# 용월리
# 진촌리
# 장계리
# 미장리
# 삼흥리
# 칠장리
# 두현리
# 죽산리
# 장원리
# 당목리
# 죽림리
# 정수리
# 양지리
# 추곡리
# 추계리
# 제일리
# 방도리
# 식금리
# 유정리
# 작촌리
# 오천리
# 이평리
# 회억리
# 이치리
# 각평리
# 단천리
# 동산리
# 주박리
# 주미리
# 신갈리
# 소고리
# 대보리
# 상천리
# 상색리
# 호명리
# 복장리
# 산유리
# 이화리
# 달전리
# 금대리
# 석정리
# 옹정리
# 송마리
# 고정리
# 갈산리
# 서암리
# 마송리
# 초원지리
# 율생리
# 대능리
# 거물대리
# 귀전리
# 도사리
# 오니산리
# 유현리
# 흥신리
# 양곡리
# 구래리
# 학운리
# 양택리
# 원산리
# 동을산리
# 수참리
# 대포리
# 석탄리
# 마곡리
# 마조리
# 후평리
# 하사리
# 누산리
# 전류리
# 석모리
# 시암리
# 성동리
# 법흥리
# 대동리
# 태리
# 향산리
# 풍곡리
# 신곡리
# 전호리
# 삼하리
# 삼상리
# 교현리
# 검복리
# 불당리
# 상동리
# 외방리
# 행현리
# 연하리
# 임초리
# 입석리
# 항사리
# 대성리
# 덕현리
# 청평리
# 하천리
# 이동교리
# 무림리
# 무봉리
# 용암리
# 청학리
# 광전리
# 퇴계원리
# 내각리
# 내곡리
# 신월리
# 진관리
# 직동리
# 고모리
# 장현리
# 연평리
# 용정리
# 사능리
# 마명리
# 금현리
# 진목리
# 배양리
# 송능리
# 팔야리
# 우금리
# 음현리
# 진벌리
# 팔현리
# 소학리
# 율석리
# 월문리
# 직두리
# 신팔리
# 명덕리
# 내방리
# 묵현리
# 녹촌리
# 율길리
# 지둔리
# 가곡리
# 울대리
# 서리
# 가실리
# 마성리
# 능원리
# 동림리
# 유운리
# 천리
# 영문리
# 전대리
# 둔전리
# 갈담리
# 금어리
# 초부리
# 삼계리
# 일산리
# 주북리
# 묵리
# 왕산리
# 송문리
# 학일리
# 도웅리
# 상림리
# 오전리
# 광지원리
# 상번천리
# 하번천리
# 대쌍령리
# 지월리
# 쌍동리
# 산이리
# 엄미리
# 도마리
# 무수리
# 분원리
# 오리
# 광동리
# 정지리
# 서하리
# 무갑리
# 용수리
# 선동리
# 원당리
# 학동리
# 열미리
# 장심리
# 갈현리
# 축현리
# 금승리
# 덕은리
# 능안리
# 위전리
# 영태리
# 등원리
# 봉일천리
# 대원리
# 뇌조리
# 도내리
# 장곡리
# 분수리
# 용미리
# 영장리
# 일영리
# 석현리
# 부곡리
# 복지리
# 금남리
# 수입리
# 삼회리
# 노문리
# 도장리
# 명달리
# 이천리
# 구암리
# 답내리
# 궁평리
# 삼리
# 늑현리
# 곤지암리
# 오향리
# 부항리
# 만선리
# 진중리
# 팔당리
# 조안리
# 시우리
# 능내리
# 차산리
# 마석우리
# 창현리
# 삼봉리
# 운수리
# 봉수리
# 화현리
# 원흥리
# 신상리
# 태봉리
# 유동리
# 운악리
# 현리
# 방성리
# 이석리
# 우천리
# 덕소리
# 정동리
# 만우리
# 오금리
# 강정리
# 노하리
# 석곶리
# 문지리
# 노상리
# 낙하리
# 거곡리
# 내포리
# 능산리
# 칠곡리
# 성주리
# 성은리
# 동항리
# 덕봉리
# 방신리
# 방아리
# 산정리
# 명목리
# 어비리
# 삼암리
# 마정리
# 양기리
# 신두리
# 장서리
# 석화리
# 웅교리
# 이현리
# 구장리
# 명당리
# 죽리
# 조일리
# 필산리
# 무능리
# 소내리
# 신령리
# 방축리
# 신창리
# 모산리
# 건지리
# 보동리
# 가유리
# 대갈리
# 토현리
# 진현리
# 월향리
# 봉산리
# 대농리
# 삼한리
# 신장리
# 기좌리
# 이전리
# 적가리
# 불현리
# 구사리
# 삼은리
# 가율리
# 복평리
# 곡천리
# 오두리
# 신안리
# 북좌리
# 상삼리
# 개정리
# 고지리
# 법전리
# 마산리
# 현매리
# 갈전리
# 강덕리
# 송정리
# 보체리
# 양변리
# 계륵리
# 구수리
# 동촌리
# 북산리
# 산평리
# 인리
# 신능리
# 신기리
# 청용리
# 장죽리
# 석하리
# 상중리
# 주월리
# 가월리
# 통구리
# 구읍리
# 객현리
# 학곡리
# 율포리
# 설마리
# 어유지리
# 마전리
# 삼화리
# 늘목리
# 황방리
# 유촌리
# 동이리
# 마포리
# 적암리
# 우정리
# 봉암리
# 간파리
# 남계리
# 양원리
# 소현리
# 구례리
# 동신리
# 개산리
# 내우리
# 양복리
# 신양복리
# 금광리
# 한운리
# 오흥리
# 현곡리
# 사흥리
# 옥정리
# 두교리
# 심곡리
# 가채리
# 신평리
# 삼성당리
# 하성북리
# 거사리
# 가양리
# 기지리
# 상성북리
# 영송리
# 만세교리
# 양문리
# 금주리
# 지현리
# 길명리
# 당동리
# 문산리
# 선유리
# 봉서리
# 향양리
# 파주리
# 동문리
# 연풍리
# 신산리
# 두포리
# 삼방리
# 법원리
# 발랑리
# 갈곡리
# 비암리
# 오현리
# 우고리
# 신계리
# 동고리
# 석봉리
# 원정리
# 안정리
# 근내리
# 신호리
# 신궁리
# 두리
# 객사리
# 송화리
# 추팔리
# 산하리
# 내가천리
# 외가천리
# 지문리
# 반제리
# 완장리
# 덕성리
# 창리
# 송전리
# 시미리
# 화산리
# 묘봉리
# 난실리
# 미산리
# 쌍지리
# 초과리
# 사정리
# 삼율리
# 탄동리
# 운천리
# 소회산리
# 대회산리
# 문암리
# 야미리
# 냉정리
# 자일리
# 방목리
# 서곡리
# 초리
# 하포리
# 매현리
# 동파리
# 고랑포리
# 반정리
# 용산리
# 항동리
# 자작리
# 금파리
# 장좌리
# 장파리
# 자장리
# 눌노리
# 답곡리
# 덕천리
# 판부리
# 식현리
# 웅담리
# 두지리
# 전동리
# 마지리
# 직천리
# 무건리
# 효촌리
# 신암리
# 송우리
# 고잔상리
# 고왕리
# 고잔하리
# 강서리
# 작동리
# 고장리
# 동중리
# 적음리
# 횡산리
# 중사리
# 어적산리
# 북삼리
# 강내리
# 도연리
# 적거리
# 삼곶리
# 마거리
# 선곡리
# 합수리
# 신현리
# 옥계리
# 상리
# 와초리
# 고능리
# 황지리
# 은대리
# 전곡리
# 초성리
# 장탄리
# 대전리
# 통현리
# 신답리
# 고문리
# 백의리
# 동막리
# 진상리
# 왕림리
# 삼거리
# 차탄리
# 현가리
# 도신리
# 대광리
# 내산리
# 중리
# 선적리
# 조산리
# 어용리
# 동장리
# 도라산리
# 금릉리
# 점원리
# 백연리
# 포춘리
# 기곡리
# 백령리
# 두일리
# 고소성리
# 운산리
# 오가리
# 추동리
# 삼정리
# 금동리
# 주원리
# 고일리
# 갈월리
# 계류리
# 영평리
# 초가팔리
# 이가팔리
# 정교리
# 감암리
# 유교리
# 좌의리
# 명산리
# 노와리
# 도밀리
# 한산리
# 하패리
# 운암리
# 선암리
# 덕둔리
# 노동리
# 무등리
# 남산리
# 대사리
# 평궁리
# 중복리
# 진사리
# 건천리
# 승두리
# 만정리
# 목신리
# 보구곶리
# 용강리
# 조강리
# 고막리
# 가금리
# 마근포리
# 사목리
# 정자리
# 장산리
# 임진리
# 창만리
# 덕도리
# 홍죽리
# 가업리
# 두곡리
# 광석리
# 상수리
# 경신리
# 입암리
# 가납리
# 도하리
# 수면리
# 음양리
# 덕절리
# 수월암리
# 적봉리
# 사리
# 금암리
# 하북리
# 야막리
# 견산리
# 갈곶리
# 청호리
# 고현리
# 동천리
# 봉남리
# 통삼리
# 북리
# 성해리
# 현화리
# 운정리
# 권관리
# 장수리
# 학현리
# 인광리
# 황산리
# 안중리
# 송담리
# 대안리
# 덕목리
# 대반리
# 신왕리
# 노양리
# 고포리
# 지화리
# 독지리
# 시리
# 신외리
# 장전리
# 유포리
# 덕우리
# 후사리
# 용성리
# 양교리
# 토진리
# 길음리
# 숙성리
# 당거리
# 도두리
# 안화리
# 교포리
# 신리
# 창내리
# 대추리
# 본정리
# 함정리
# 동창리
# 포내리
# 고양리
# 쇄암리
# 군하리
# 대명리
# 약암리
# 대벽리
# 상마리
# 수화리
# 남전리
# 북양리
# 양노리
# 원리
# 야목리
# 구포리
# 자안리
# 숙곡리
# 어천리
# 상기리
# 원평리
# 천천리
# 수영리
# 동화리
# 분천리
# 와우리
# 송교리
# 장외리
# 백미리
# 매향리
# 광평리
# 상안리
# 홍법리
# 육일리
# 백곡리
# 청원리
# 호곡리
# 운평리
# 석교리
# 원안리
# 쌍송리
# 화수리
# 장덕리
# 남양리
# 주곡리
# 한각리
# 조암리
# 멱우리
# 원천리
# 석포리
# 안석리
# 금의리
# 사랑리
# 어은리
# 활초리
# 무송리
# 독정리
# 온석리
# 서근리
# 수촌리
# 하저리
# 율암리
# 창곡리
# 고주리
# 청요리
# 기천리
# 하길리
# 대양리
# 요당리
# 고렴리
# 행정리
# 화리현리
# 도이리
# 백토리
# 하가등리
# 상두리
# 어소리
# 문학리
# 요리
# 사창리
# 증거리
# 율북리
# 어연리
# 문곡리
# 동청리
# 해창리
# 두릉리
# 장등리
# 당현리
# 용소리
# 정문리
# 황구지리
# 회화리
# 금각리
# 은산리
# 봉명리
# 봉무리
# 원암리
# 전궁리
# 아곡리
# 노성리
# 두정리
# 석근리
# 마하리
# 백리
# 덕리
# 당하리
# 관항리
# 오일리
# 길성리
# 수기리
# 괘랑리
# 계향리
# 갈천리
# 발산리
# 귀래리
# 수직리
# 내천리
# 마두리
# 금복리
# 망월리
# 제기리
# 제부리
# 천등리
# 중송리
# 쌍정리
# 사강리
# 삼존리
# 해문리
# 봉가리
# 용포리
# 슬항리
# 노진리
# 덕다리
# 만호리
# 홍원리
# 내기리
# 화당리
# 신영리
# 희곡리
# 고잔리
# 방림리
# 상신리
# 구문천리
# 제암리
# 발안리
# 옥길리
# 장짐리
# 가재리
# 평리
# 세곡리
# 유리

# %%
ri_names = df_ggl['상세주소.3'].unique()

df_gg['history'] = df_gg['RI_NM'].isin(ri_names).astype(int)
df_gg['history'].value_counts()
# Out:
# history
# 0    157720
# 1     22785
# Name: count, dtype: int64

# %%
df_gg.columns
# Out:
# Index(['year', 'month', 'day', 'sm', 'longitude', 'latitude', 'geometry',
#        '법정동명', 'RI_NM', '일시', '시군구', '일강수량(mm)', 'matched_latitude',
#        'matched_longitude', 'matched_mean', 'distance_km', 'elevation',
#        'matched_slope', 'history'],
#       dtype='object')

# %%
df_gg.rename(columns={'matched_elevation': 'elevation'}, inplace=True)

# %%
df_gg.rename(columns={'matched_slope': 'slope'}, inplace=True)

# %%
ml_gg = df_gg[['matched_mean','elevation', 'slope','sm','일강수량(mm)','history']]

ml_gg
# Out:
#         matched_mean   elevation      slope      sm  일강수량(mm)  history
# 0           0.638810  412.488315  16.333490   68.56    40.000        0
# 1           0.620675  459.240738  21.248910   68.56    40.000        0
# 2           0.613589  464.567465  20.017375   68.56    40.000        0
# 3           0.648113  519.436188  22.400142   68.56    40.000        0
# 4           0.612092  335.324895  13.556068   68.56    40.000        0
# ...              ...         ...        ...     ...       ...      ...
# 180500      0.459676  102.317273  11.063213  108.45    10.375        0
# 180501      0.363704   38.048671   4.039405  108.45    10.500        0
# 180502      0.353189   35.938312   4.143402  108.45    10.500        0
# 180503      0.206488   26.317023   2.060655  108.45    10.500        0
# 180504      0.325241   51.573802   4.619743  108.45    10.500        0
#
# [180505 rows x 6 columns]

# %% [markdown]
# ## 머신러닝 1차 시도 -- 로지스틱 회귀 (0,1 재현율 극단적)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


X = ml_gg[['matched_mean', 'elevation', 'slope', 'sm', '일강수량(mm)']]
y = ml_gg['history']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)


model = LogisticRegression(class_weight='balanced', random_state=42)
model.fit(X_train, y_train)


y_proba = model.predict_proba(X_test)[:, 1]
y_pred = (y_proba > 0.3).astype(int)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# [[ 7548 23996]
#  [  341  4216]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.24      0.38     31544
#            1       0.15      0.93      0.26      4557
#
#     accuracy                           0.33     36101
#    macro avg       0.55      0.58      0.32     36101
# weighted avg       0.85      0.33      0.37     36101

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.legend()
plt.grid()
plt.title("Precision-Recall vs Threshold")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

X = ml_gg[['matched_mean','elevation', 'slope','sm','일강수량(mm)']]
y = ml_gg['history']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[31544     0]
#  [ 4557     0]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     31544
#            1       0.00      0.00      0.00      4557
#
#     accuracy                           0.87     36101
#    macro avg       0.44      0.50      0.47     36101
# weighted avg       0.76      0.87      0.81     36101
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Recalculate scale_pos_weight from training set
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train XGBoost without SMOTE, just using scale_pos_weight
model_no_smote = XGBClassifier(
    scale_pos_weight=scale_pos_weight,
    eval_metric='logloss',
    random_state=42
)
model_no_smote.fit(X_train_scaled, y_train)

# Predict probabilities and apply threshold tuning
y_proba_no_smote = model_no_smote.predict_proba(X_test_scaled)[:, 1]
y_pred_no_smote = (y_proba_no_smote > 0.4).astype(int)

# Evaluate
conf_matrix_no_smote = confusion_matrix(y_test, y_pred_no_smote)
report_no_smote = classification_report(y_test, y_pred_no_smote, zero_division=0)
roc_auc_no_smote = roc_auc_score(y_test, y_proba_no_smote)

print(conf_matrix_no_smote, report_no_smote, roc_auc_no_smote)
# Out:
# [[25777  5767]
#  [  212  4345]]               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90     31544
#            1       0.43      0.95      0.59      4557
#
#     accuracy                           0.83     36101
#    macro avg       0.71      0.89      0.74     36101
# weighted avg       0.92      0.83      0.86     36101
#  0.9526391438988693

# %%
import shap
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


X = df_gg[['matched_mean', 'elevation', 'slope', 'sm', '일강수량(mm)']]
y = df_gg['history']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. XGBoost 모델 학습 (scale_pos_weight 반영)
scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
model = xgb.XGBClassifier(scale_pos_weight=scale_pos_weight, eval_metric='logloss', random_state=42)
model.fit(X_train_scaled, y_train)

# 3. SHAP 분석
explainer = shap.Explainer(model)
shap_values = explainer(X_test_scaled)

# 4. 요약 그래프 (전체 변수 중요도)
shap.summary_plot(shap_values, X_test, feature_names=X.columns)

# 5. 개별 예측 해석 (예: 0번째 샘플)
shap.plots.waterfall(shap_values[0])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:1153: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   pl.tight_layout()
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import shap
import pandas as pd
import numpy as np

explainer = shap.Explainer(model, X_train_scaled)
shap_values = explainer(X_test_scaled)

mean_shap_df = pd.DataFrame({
    'feature': X.columns,
    'mean_abs_shap': np.abs(shap_values.values).mean(axis=0)
}).sort_values(by='mean_abs_shap', ascending=False)

print(mean_shap_df)
# Out:
#  99%|===================| 35864/36101 [01:54<00:00]
#         feature  mean_abs_shap
# 3            sm       1.426622
# 1     elevation       0.978124
# 2         slope       0.590684
# 0  matched_mean       0.503327
# 4      일강수량(mm)       0.355059

# %%
import pandas as pd

# 세 지역의 SHAP 값 데이터
data = {
    'Feature': ['sm', 'elevation', 'slope', 'matched_mean', '일강수량(mm)'],
    'Gyeonggi': [1.426622, 0.978124, 0.590684, 0.503327, 0.355059],
    'Chungnam': [1.108072, 0.651326, 0.366975, 0.341592, 0.554826],
    'Gyeongbuk': [0.978405, 0.559139, 0.379025, 0.364736, 1.182433]
}

# 데이터프레임 생성
shap_df = pd.DataFrame(data)
shap_df = shap_df[['Feature', 'Gyeonggi', 'Chungnam', 'Gyeongbuk']]

shap_df
# Out:
#         Feature  Gyeonggi  Chungnam  Gyeongbuk
# 0            sm  1.426622  1.108072   0.978405
# 1     elevation  0.978124  0.651326   0.559139
# 2         slope  0.590684  0.366975   0.379025
# 3  matched_mean  0.503327  0.341592   0.364736
# 4      일강수량(mm)  0.355059  0.554826   1.182433
